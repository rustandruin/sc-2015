# %%
# %matplotlib inline
#%config InlineBackend.figure_format = 'svg'
from matplotlib import pyplot as plt
import numpy as np
from spark_msi import MSIDataset

# %%
# The following files are on edison at /project/projectdirs/openmsi/projects/mantissa/ddalisay/2014Nov15_PDX_IMS_imzML
imzXMLPath = 'Lewis_Dalisay_Peltatum_20131115_PDX_Std_1.imzml'                                                       
imzBinPath = "Lewis_Dalisay_Peltatum_20131115_PDX_Std_1.ibd" 
dataset = MSIDataset.from_imzml(sc, imzXMLPath, imzBinPath).cache()

# Alternatively for efficiency, save once and then load:
#  dataset.save("Lewis_Dalisay_Peltatum_20131115_PDX_Std_1.rdd")
#  ...
#  dataset = MSIDataset.load(sc, "Lewis_Dalisay_Peltatum_20131115_PDX_Std_1.rdd")

# %%
imshow(dataset.image())

# %%
plot(*dataset.histogram())

# %%
# Selection of only ions with mz of 414 to 454
pdx = dataset.select_mz_range(414.0, 454.0).cache()

# %%
plot(*pdx.histogram())

# %%
# Plot single "pixel" from the cube
plot(*dataset.select1(32, 21, 0).histogram())

# %%
# Plot single "pixel" from the PDX cube
plot(*pdx.select1(32, 21, 0).histogram())
